# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# pip install --upgrade pip
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f DeepGitStream/requirements.txt
#   then
#     pip install -r ./DeepGitStream/requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (23.2.1)
# Requirement already satisfied: streamlit in /root/venv/lib/python3.9/site-packages (from -r ./DeepGitStream/requirements.txt (line 1)) (1.27.2)
# Requirement already satisfied: pandas in /root/venv/lib/python3.9/site-packages (from -r ./DeepGitStream/requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: altair in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./DeepGitStream/requirements.txt (line 3)) (4.2.2)
# Requirement already satisfied: Pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./DeepGitStream/requirements.txt (line 4)) (9.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /root/venv/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (5.2.0)
# Requirement already satisfied: click<9,>=7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: packaging<24,>=16.8 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (21.3)
# Requirement already satisfied: protobuf<5,>=3.20 in /root/venv/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (4.24.4)
# Requirement already satisfied: pyarrow>=6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: rich<14,>=10.14.0 in /root/venv/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (13.6.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (8.1.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /root/venv/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (4.2)
# Requirement already satisfied: validators<1,>=0.2 in /root/venv/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /root/venv/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /root/venv/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (6.2)
# Requirement already satisfied: watchdog>=2.1.5 in /root/venv/lib/python3.9/site-packages (from streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./DeepGitStream/requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./DeepGitStream/requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair->-r ./DeepGitStream/requirements.txt (line 3)) (0.4)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair->-r ./DeepGitStream/requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair->-r ./DeepGitStream/requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: toolz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from altair->-r ./DeepGitStream/requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /root/venv/lib/python3.9/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata<7,>=1.4->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r ./DeepGitStream/requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r ./DeepGitStream/requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r ./DeepGitStream/requirements.txt (line 3)) (58.1.0)
# Requirement already satisfied: six>=1.11.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r ./DeepGitStream/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging<24,>=16.8->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->altair->-r ./DeepGitStream/requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /root/venv/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tzlocal<6,>=1.1->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (0.1.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /root/venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: mdurl~=0.1 in /root/venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r ./DeepGitStream/requirements.txt (line 1)) (0.1.2)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f0221a45-0b06-4f48-8b45-d2c73f2b055a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
