# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# pip install --upgrade pip
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (23.0.1)
# Collecting pip
#   Downloading pip-23.2.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 60.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-23.2.1
# Collecting streamlit (from -r ./requirements.txt (line 1))
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/34/01/9d1460a6e71d6226e1f5c5053de20758c41100c5c15abb73551273a96fb8/streamlit-1.27.2-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.27.2-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (1.2.5)
# Requirement already satisfied: altair in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (4.2.2)
# Requirement already satisfied: Pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 4)) (9.2.0)
# Collecting blinker<2,>=1.0.0 (from streamlit->-r ./requirements.txt (line 1))
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (5.2.0)
# Requirement already satisfied: click<9,>=7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: packaging<24,>=16.8 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (21.3)
# Collecting pandas (from -r ./requirements.txt (line 2))
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/bc/7e/a9e11bd272e3135108892b6230a115568f477864276181eada3a35d03237/pandas-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pandas-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting protobuf<5,>=3.20 (from streamlit->-r ./requirements.txt (line 1))
#   Obtaining dependency information for protobuf<5,>=3.20 from https://files.pythonhosted.org/packages/c8/2c/03046cac73f46bfe98fc846ef629cf4f84c2f59258216aa2cc0d22bfca8f/protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Requirement already satisfied: pyarrow>=6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (2.28.1)
# Collecting rich<14,>=10.14.0 (from streamlit->-r ./requirements.txt (line 1))
#   Obtaining dependency information for rich<14,>=10.14.0 from https://files.pythonhosted.org/packages/be/2a/4e62ff633612f746f88618852a626bbe24226eba5e7ac90e91dcfd6a414e/rich-13.6.0-py3-none-any.whl.metadata
#   Downloading rich-13.6.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (8.1.0)
# Collecting toml<2,>=0.10.1 (from streamlit->-r ./requirements.txt (line 1))
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (4.2)
# Collecting validators<1,>=0.2 (from streamlit->-r ./requirements.txt (line 1))
#   Obtaining dependency information for validators<1,>=0.2 from https://files.pythonhosted.org/packages/3a/0c/785d317eea99c3739821718f118c70537639aa43f96bfa1d83a71f68eaf6/validators-0.22.0-py3-none-any.whl.metadata
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->-r ./requirements.txt (line 1))
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/8a/7e/20f7e45878b5aed34320fbeeae8f78acc806e7bd708d00b1c6e64b016f5b/GitPython-3.1.37-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.37-py3-none-any.whl.metadata (12 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r ./requirements.txt (line 1))
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 46.4 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (6.2)
# Collecting watchdog>=2.1.5 (from streamlit->-r ./requirements.txt (line 1))
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair->-r ./requirements.txt (line 3)) (0.4)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair->-r ./requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair->-r ./requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: toolz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from altair->-r ./requirements.txt (line 3)) (0.12.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ./requirements.txt (line 1))
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata<7,>=1.4->streamlit->-r ./requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r ./requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r ./requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r ./requirements.txt (line 3)) (58.1.0)
# Requirement already satisfied: six>=1.11.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging<24,>=16.8->streamlit->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->altair->-r ./requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit->-r ./requirements.txt (line 1)) (2022.9.24)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->-r ./requirements.txt (line 1))
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit->-r ./requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tzlocal<6,>=1.1->streamlit->-r ./requirements.txt (line 1)) (0.1.0.post0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ./requirements.txt (line 1))
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r ./requirements.txt (line 1))
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading streamlit-1.27.2-py2.py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 78.5 MB/s eta 0:00:00
# Downloading pandas-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 94.6 MB/s eta 0:00:00
# Downloading GitPython-3.1.37-py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 41.3 MB/s eta 0:00:00
# Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 52.3 MB/s eta 0:00:00
# Downloading rich-13.6.0-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.8/239.8 kB 45.6 MB/s eta 0:00:00
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 24.3 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, validators, toml, smmap, protobuf, mdurl, blinker, pydeck, pandas, markdown-it-py, gitdb, rich, gitpython, streamlit
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Not uninstalling protobuf at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'protobuf'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-spanner 3.36.0 requires sqlparse>=0.4.4, but you have sqlparse 0.4.3 which is incompatible.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.4 which is incompatible.
# tensorflow 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.4 which is incompatible.
# Successfully installed blinker-1.6.2 gitdb-4.0.10 gitpython-3.1.37 markdown-it-py-3.0.0 mdurl-0.1.2 pandas-2.1.1 protobuf-4.24.4 pydeck-0.8.1b0 rich-13.6.0 smmap-5.0.1 streamlit-1.27.2 toml-0.10.2 validators-0.22.0 watchdog-3.0.0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f0221a45-0b06-4f48-8b45-d2c73f2b055a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
